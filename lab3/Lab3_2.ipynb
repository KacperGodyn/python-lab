# %%
import pytest

pytest.main(["-v", "test_product_pytest.py"])
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.14.3, pytest-9.0.3, pluggy-1.6.0 -- c:\_repos\AAP_LAB_TASKS\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\_repos\python-lab\lab3
# configfile: pytest.ini
# plugins: anyio-4.13.0
# collecting ... collected 14 items
#
# test_product_pytest.py::test_is_available PASSED                         [  7%]
# test_product_pytest.py::test_total_value PASSED                          [ 14%]
# test_product_pytest.py::test_add_stock_parametrized[5-15] PASSED         [ 21%]
# test_product_pytest.py::test_add_stock_parametrized[0-10] PASSED         [ 28%]
# test_product_pytest.py::test_add_stock_parametrized[100-110] PASSED      [ 35%]
# test_product_pytest.py::test_apply_discount_valid[0-100.0] PASSED        [ 42%]
# test_product_pytest.py::test_apply_discount_valid[50-50.0] PASSED        [ 50%]
# ...
