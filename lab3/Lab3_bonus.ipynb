# %%
import pytest

pytest.main(["-v", "test_product_pytest.py", "-k", "apply_discount"])
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.14.3, pytest-9.0.3, pluggy-1.6.0 -- c:\_repos\AAP_LAB_TASKS\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\_repos\python-lab\lab3
# configfile: pytest.ini
# plugins: anyio-4.13.0
# collecting ... collected 14 items / 7 deselected / 7 selected
#
# test_product_pytest.py::test_apply_discount_valid[0-100.0] PASSED        [ 14%]
# test_product_pytest.py::test_apply_discount_valid[50-50.0] PASSED        [ 28%]
# test_product_pytest.py::test_apply_discount_valid[100-0.0] PASSED        [ 42%]
# test_product_pytest.py::test_apply_discount_invalid_raises[-10] PASSED   [ 57%]
# test_product_pytest.py::test_apply_discount_invalid_raises[-1] PASSED    [ 71%]
# test_product_pytest.py::test_apply_discount_invalid_raises[101] PASSED   [ 85%]
# test_product_pytest.py::test_apply_discount_invalid_raises[150] PASSED   [100%]
#
# ...
