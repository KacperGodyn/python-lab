# %%
import logging

logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s', force=True)

class AccessLogger:
    def __set_name__(self, owner, name):
        self.name = name

    def __get__(self, instance, owner):
        if instance is None:
            return self
        value = instance.__dict__.get(self.name)
        logging.info(f"Odczyt atrybutu '{self.name}': {value}")
        return value

    def __set__(self, instance, value):
        logging.info(f"Zapis atrybutu '{self.name}': {value}")
        instance.__dict__[self.name] = value

class Uzytkownik:
    imie = AccessLogger()
    wiek = AccessLogger()

    def __init__(self, imie, wiek):
        self.imie = imie
        self.wiek = wiek

# Test
if __name__ == "__main__":
    u = Uzytkownik("Jan", 30)
    print(f"Imię: {u.imie}")
    u.wiek = 31
    print(f"Wiek: {u.wiek}")
# Out:
# INFO: Zapis atrybutu 'imie': Jan
# INFO: Zapis atrybutu 'wiek': 30
# INFO: Odczyt atrybutu 'imie': Jan
# INFO: Zapis atrybutu 'wiek': 31
# INFO: Odczyt atrybutu 'wiek': 31
# Imię: Jan
# Wiek: 31
